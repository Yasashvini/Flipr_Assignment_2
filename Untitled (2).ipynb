# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.model_selection import train_test_split
df=pd.read_csv('Sample_data.csv');
df
# Out:
#             id      price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0   7129300520   221900.0         3       1.00         1180      5650     1.0
# 1   6414100192   538000.0         3       2.25         2570      7242     2.0
# 2   5631500400   180000.0         2       1.00          770     10000     1.0
# 3   2487200875   604000.0         4       3.00         1960      5000     1.0
# 4   1954400510   510000.0         3       2.00         1680      8080     1.0
# 5   7237550310  1230000.0         4       4.50         5420    101930     1.0
# 6   1321400060   257500.0         3       2.25         1715      6819     2.0
# 7   2008000270   291850.0         3       1.50         1060      9711     1.0
# 8   2414600126   229500.0         3       1.00         1780      7470     1.0
# 9   3793500160   323000.0         3       2.50         1890      6560     2.0
# 10  1736800520   662500.0         3       2.50         3560      9796     1.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 10 columns):
# id             50 non-null int64
# price          50 non-null float64
# bedrooms       50 non-null int64
# bathrooms      50 non-null float64
# sqft_living    50 non-null int64
# sqft_lot       50 non-null int64
# floors         50 non-null float64
# condition      50 non-null int64
# grade          50 non-null int64
# zipcode        50 non-null int64
# dtypes: float64(3), int64(7)
# memory usage: 4.0 KB

# %%
df.isnull().sum()#no null values
# Out:
# id             0
# price          0
# bedrooms       0
# bathrooms      0
# sqft_living    0
# sqft_lot       0
# floors         0
# condition      0
# grade          0
# zipcode        0
# dtype: int64

# %%
 cols = ['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors','condition','grade','price'] 
sb.pairplot(df[cols], size=2.5); 
plt.show()
# Out:
# C:\Users\YASASH\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
correlation_matrix = df.corr().round(2)
sb.heatmap(data=correlation_matrix, annot=True)

# %%
from sklearn import linear_model
train_data,test_data=train_test_split(df,train_size=0.8,random_state=3)
linear=linear_model.LinearRegression()
x_train=np.array(train_data['sqft_living']).reshape(-1,1)
y_train=np.array(train_data['price']).reshape(-1,1)
linear.fit(x_train,y_train)
# Out:
# C:\Users\YASASH\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2179: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
 def lin_regplot(X, y, model):
        plt.scatter(X, y, c='blue')
        plt.plot(X, model.predict(X), color='red') 
        return None 
lin_regplot(x_train, y_train, linear) 
plt.xlabel('Sqft living')
plt.ylabel('Price')
plt.show()

# %%
from sklearn import metrics
x_test=np.array(test_data['grade']).reshape(-1,1)
y_test=np.array(test_data['price']).reshape(-1,1)
pred=linear.predict(x_test)
mean_squared_error=metrics.mean_squared_error(y_test,pred)
print('squared mean error',round(np.sqrt(mean_squared_error),2))
print('R squared training',round(linear.score(x_train,y_train),3))
# Out:
# squared mean error 406934.71
# R squared training 0.425
# R sqaured testing -5.919
